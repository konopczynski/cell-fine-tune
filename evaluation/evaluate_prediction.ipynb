# %%
import numpy as np
import matplotlib.pyplot as plt
import os
from skimage.measure import label, regionprops
import pandas as pd

from utils_eval import TestDataset, describe

#provide path to folder with predictions in PNG format
PRED_PATH = ''

dset = TestDataset()
dset.load_pred(PRED_PATH)
dset.get_cells()

# %% [markdown]
# ### Statistics for all the cells in the test set:

# %%
describe(dset.cell_info)
# Out:
# /home/piotr/cell_segmentation/Marie/extended_preds/utils_eval.py:14: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   ], axis=1).dropna().T
#               area  asphericity    perimeter
# count  5388.000000  5388.000000  5388.000000
# mean    324.032851     0.075378    65.086231
# std     118.520490     0.006646    15.234320
# min      51.000000     0.036445    24.485281
# 25%     247.750000     0.074774    56.627417
# 50%     315.000000     0.076394    64.284271
# 75%     388.000000     0.077851    71.941125
# max     915.000000     0.090514   146.225397
# mad      89.845785     0.003148    10.527977
# skew      0.754918    -4.405489     1.400197
# kurt      1.583333    22.042033     5.361410

# %% [markdown]
# ### Function .get_statistics() - plots histogram and prints out consequtive bins
# Parameters (default given) for .get_statistics(bins=20, logscale=False): <br>
# bins -> number of histogram bins <br>
# logscale <True/False> -> plot on logarithmic scale

# %%
dset.get_statistics(bins=40, logscale=True)
# Out:
# Dataset has in total  5388 cells
# For area:
# In range: 51.0 , 72.6 total cells:  12
# In range: 72.6 , 94.2 total cells:  47
# In range: 94.2 , 115.8 total cells:  70
# In range: 115.8 , 137.4 total cells:  119
# In range: 137.4 , 159.0 total cells:  136
# In range: 159.0 , 180.6 total cells:  160
# In range: 180.6 , 202.2 total cells:  184
# In range: 202.2 , 223.8 total cells:  255
# In range: 223.8 , 245.4 total cells:  326
# In range: 245.4 , 267.0 total cells:  354
# In range: 267.0 , 288.6 total cells:  441
# In range: 288.6 , 310.2 total cells:  494
# In range: 310.2 , 331.8 total cells:  434
# In range: 331.8 , 353.4 total cells:  448
# In range: 353.4 , 375.0 total cells:  336
# In range: 375.0 , 396.6 total cells:  340
# In range: 396.6 , 418.2 total cells:  270
# In range: 418.2 , 439.8 total cells:  213
# In range: 439.8 , 461.4 total cells:  190
# In range: 461.4 , 483.0 total cells:  110
# In range: 483.0 , 504.6 total cells:  97
# ...
